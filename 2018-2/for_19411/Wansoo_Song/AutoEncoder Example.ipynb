# %%
from __future__ import division, print_function, absolute_import

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)

# Training Parameters
learning_rate = 0.01
num_steps = 30000
batch_size = 256

display_step = 1000
examples_to_show = 10

# Network Parameters
num_hidden_1 = 256 # 1st layer num features
num_hidden_2 = 128 # 2nd layer num features (the latent dim)
num_input = 784 # MNIST data input (img shape: 28*28)

# tf Graph input (only pictures)
X = tf.placeholder("float", [None, num_input])

weights = {
    'encoder_h1': tf.Variable(tf.random_normal([num_input, num_hidden_1])),
    'encoder_h2': tf.Variable(tf.random_normal([num_hidden_1, num_hidden_2])),
    'decoder_h1': tf.Variable(tf.random_normal([num_hidden_2, num_hidden_1])),
    'decoder_h2': tf.Variable(tf.random_normal([num_hidden_1, num_input])),
}
biases = {
    'encoder_b1': tf.Variable(tf.random_normal([num_hidden_1])),
    'encoder_b2': tf.Variable(tf.random_normal([num_hidden_2])),
    'decoder_b1': tf.Variable(tf.random_normal([num_hidden_1])),
    'decoder_b2': tf.Variable(tf.random_normal([num_input])),
}

# Building the encoder
def encoder(x):
    # Encoder Hidden layer with sigmoid activation #1
    layer_1 = tf.nn.sigmoid(tf.add(tf.matmul(x, weights['encoder_h1']),
                                   biases['encoder_b1']))
    # Encoder Hidden layer with sigmoid activation #2
    layer_2 = tf.nn.sigmoid(tf.add(tf.matmul(layer_1, weights['encoder_h2']),
                                   biases['encoder_b2']))
    return layer_2


# Building the decoder
def decoder(x):
    # Decoder Hidden layer with sigmoid activation #1
    layer_1 = tf.nn.sigmoid(tf.add(tf.matmul(x, weights['decoder_h1']),
                                   biases['decoder_b1']))
    # Decoder Hidden layer with sigmoid activation #2
    layer_2 = tf.nn.sigmoid(tf.add(tf.matmul(layer_1, weights['decoder_h2']),
                                   biases['decoder_b2']))
    return layer_2

# Construct model
encoder_op = encoder(X)
decoder_op = decoder(encoder_op)

# Prediction
y_pred = decoder_op
# Targets (Labels) are the input data.
y_true = X

# Define loss and optimizer, minimize the squared error
loss = tf.reduce_mean(tf.pow(y_true - y_pred, 2))
optimizer = tf.train.RMSPropOptimizer(learning_rate).minimize(loss)

# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

# Start Training
# Start a new TF session
print(X)
with tf.Session() as sess:

    # Run the initializer
    sess.run(init)

    # Training
    for i in range(1, num_steps+1):
        # Prepare Data
        # Get the next batch of MNIST data (only images are needed, not labels)
        batch_x, _ = mnist.train.next_batch(batch_size)
        
        # Run optimization op (backprop) and cost op (to get loss value)
        _, l = sess.run([optimizer, loss], feed_dict={X: batch_x})
        print("batch")
        print(tf.shape(batch_x))
        print("X")
        print(tf.shape(X))
        # Display logs per step
        if i % display_step == 0 or i == 1:
            print('Step %i: Minibatch Loss: %f' % (i, l))

    # Testing
    # Encode and decode images from test set and visualize their reconstruction.
    n = 4
    canvas_orig = np.empty((28 * n, 28 * n))
    canvas_recon = np.empty((28 * n, 28 * n))
    for i in range(n):
        # MNIST test set
        batch_x, _ = mnist.test.next_batch(n)
        # Encode and decode the digit image
        g = sess.run(decoder_op, feed_dict={X: batch_x})

        # Display original images
        for j in range(n):
            # Draw the original digits
            canvas_orig[i * 28:(i + 1) * 28, j * 28:(j + 1) * 28] = \
                batch_x[j].reshape([28, 28])
        # Display reconstructed images
        for j in range(n):
            # Draw the reconstructed digits
            canvas_recon[i * 28:(i + 1) * 28, j * 28:(j + 1) * 28] = \
                g[j].reshape([28, 28])

    print("Original Images")
    plt.figure(figsize=(n, n))
    plt.imshow(canvas_orig, origin="upper", cmap="gray")
    plt.show()

    print("Reconstructed Images")
    plt.figure(figsize=(n, n))
    plt.imshow(canvas_recon, origin="upper", cmap="gray")
    plt.show()
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# Tensor("Placeholder_6:0", shape=(?, 784), dtype=float32)
# batch
# Tensor("Shape_2123:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2124:0", shape=(2,), dtype=int32)
# Step 1: Minibatch Loss: 0.441922
# batch
# Tensor("Shape_2125:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2126:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2127:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2128:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2129:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2130:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2131:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2132:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2133:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2134:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2135:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2136:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2137:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2138:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2139:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2140:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2141:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2142:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2143:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2144:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2145:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2146:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2147:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2148:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2149:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2150:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2151:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2152:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2153:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2154:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2155:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2156:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2157:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2158:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2159:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2160:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2161:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2162:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2163:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2164:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2165:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2166:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2167:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2168:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2169:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2170:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2171:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2172:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2173:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2174:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2175:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2176:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2177:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2178:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2179:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2180:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2181:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2182:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2183:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2184:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2185:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2186:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2187:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2188:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2189:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2190:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2191:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2192:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2193:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2194:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2195:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2196:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2197:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2198:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2199:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2200:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2201:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2202:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2203:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2204:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2205:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2206:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2207:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2208:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2209:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2210:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2211:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2212:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2213:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2214:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2215:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2216:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2217:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2218:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2219:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2220:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2221:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2222:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2223:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2224:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2225:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2226:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2227:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2228:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2229:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2230:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2231:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2232:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2233:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2234:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2235:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2236:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2237:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2238:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2239:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2240:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2241:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2242:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2243:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2244:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2245:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2246:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2247:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2248:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2249:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2250:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2251:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2252:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2253:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2254:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2255:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2256:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2257:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2258:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2259:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2260:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2261:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2262:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2263:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2264:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2265:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2266:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2267:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2268:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2269:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2270:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2271:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2272:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2273:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2274:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2275:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2276:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2277:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2278:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2279:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2280:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2281:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2282:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2283:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2284:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2285:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2286:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2287:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2288:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2289:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2290:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2291:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2292:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2293:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2294:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2295:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2296:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2297:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2298:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2299:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2300:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2301:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2302:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2303:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2304:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2305:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2306:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2307:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2308:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2309:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2310:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2311:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2312:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2313:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2314:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2315:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2316:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2317:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2318:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2319:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2320:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2321:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2322:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2323:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2324:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2325:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2326:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2327:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2328:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2329:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2330:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2331:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2332:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2333:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2334:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2335:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2336:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2337:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2338:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2339:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2340:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2341:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2342:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2343:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2344:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2345:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2346:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2347:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2348:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2349:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2350:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2351:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2352:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2353:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2354:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2355:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2356:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2357:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2358:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2359:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2360:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2361:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2362:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2363:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2364:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2365:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2366:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2367:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2368:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2369:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2370:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2371:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2372:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2373:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2374:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2375:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2376:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2377:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2378:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2379:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2380:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2381:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2382:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2383:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2384:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2385:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2386:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2387:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2388:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2389:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2390:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2391:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2392:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2393:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2394:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2395:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2396:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2397:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2398:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2399:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2400:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2401:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2402:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2403:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2404:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2405:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2406:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2407:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2408:0", shape=(2,), dtype=int32)
# batch
# Tensor("Shape_2409:0", shape=(2,), dtype=int32)
# X
# Tensor("Shape_2410:0", shape=(2,), dtype=int32)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-f41869f9760b> in <module>()
#      90
#      91         # Run optimization op (backprop) and cost op (to get loss value)
# ---> 92         _, l = sess.run([optimizer, loss], feed_dict={X: batch_x})
#      93         print("batch")
#      94         print(tf.shape(batch_x))
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1135     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1136       results = self._do_run(handle, final_targets, final_fetches,
# -> 1137                              feed_dict_tensor, options, run_metadata)
#    1138     else:
#    1139       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1353     if handle is None:
#    1354       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1355                            options, run_metadata)
#    1356     else:
#    1357       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1359   def _do_call(self, fn, *args):
#    1360     try:
# -> 1361       return fn(*args)
#    1362     except errors.OpError as e:
#    1363       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1330                 run_metadata):
#    1331       # Ensure any changes to the graph are reflected in the runtime.
# -> 1332       self._extend_graph()
#    1333       with errors.raise_exception_on_not_ok_status() as status:
#    1334         if self._created_with_new_api:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _extend_graph(self)
#    1390         with errors.raise_exception_on_not_ok_status() as status:
#    1391           tf_session.TF_ExtendGraph(self._session,
# -> 1392                                     graph_def.SerializeToString(), status)
#    1393         self._opened = True
#    1394
#
# KeyboardInterrupt:
