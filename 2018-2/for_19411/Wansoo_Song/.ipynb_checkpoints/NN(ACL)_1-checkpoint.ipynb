# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import statsmodels.formula.api as sm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn import cross_validation
import tensorflow as tf
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
data = np.genfromtxt('acl data.txt') # The default path is same with this ipynb

X_before = data[:,0:4] #The ":" means include whole range of array. 0:4 means to include numbers from 0th to 3rd column.
Y_before = data[:,4] #4 means to include numbers from 4th column.
X = (X_before-np.min(X_before))/(np.max(X_before)-np.min(X_before))
Y = (Y_before-min(Y_before))/(max(Y_before)-min(Y_before))   #nomalizing
# 배치 전체를 normalize? 하나의 수로?

dfX=pd.DataFrame(X) #Include X to dfX, and make it to table type.
dfy=pd.DataFrame(Y)

table=pd.concat([dfX, dfy], axis=1) #If axis = 1, then concat to right side. Otherwise (axis = 0), then concat to bottom side.
                                    #Also, if they have sharing indexes or columns, then it will be write on the same indexes or columns.
                                    #But, if it doesn't, then it will be write on the different indexes or columns, 
                                    #and it will be appear as NaN in the not shared parameters.
table.columns=['Power','Pressure','C3H6','N2','Thickness_Top'] #P

table
# Out:
#        Power  Pressure      C3H6        N2  Thickness_Top
# 0   0.188034   0.82906  0.059829  0.017094       0.292727
# 1   0.188034   0.65812  0.042735  0.017094       0.000000
# 2   0.170940   0.65812  0.042735  0.008547       0.051818
# 3   0.170940   0.82906  0.059829  0.008547       0.256364
# 4   0.188034   0.82906  0.042735  0.008547       0.409091
# 5   0.205128   0.82906  0.042735  0.017094       0.272727
# 6   0.188034   0.82906  0.025641  0.017094       0.582727
# 7   0.205128   0.65812  0.042735  0.008547       0.138182
# 8   0.188034   0.82906  0.025641  0.000000       0.589091
# 9   0.188034   0.65812  0.025641  0.008547       0.278182
# 10  0.188034   0.82906  0.059829  0.000000       0.392727
# 11  0.170940   0.82906  0.042735  0.000000       0.530000
# 12  0.205128   1.00000  0.042735  0.008547       1.000000
# 13  0.188034   0.65812  0.059829  0.008547       0.089091
# 14  0.170940   1.00000  0.042735  0.008547       0.648182
# 15  0.205128   0.82906  0.042735  0.000000       0.337273
# 16  0.170940   0.82906  0.025641  0.008547       0.576364
# 17  0.188034   1.00000  0.059829  0.008547       0.468182
# 18  0.188034   1.00000  0.042735  0.000000       0.617273
# 19  0.188034   0.82906  0.042735  0.008547       0.320000
# 20  0.205128   0.82906  0.059829  0.008547       0.260000
# 21  0.188034   1.00000  0.025641  0.008547       0.853636
# 22  0.188034   0.65812  0.042735  0.000000       0.099091
# 23  0.205128   0.82906  0.025641  0.008547       0.640000
# 24  0.170940   0.82906  0.042735  0.017094       0.340909
# 25  0.188034   0.82906  0.042735  0.008547       0.383636
# 26  0.188034   1.00000  0.042735  0.017094       0.560000

# %%
X_train, X_test, Y_train, Y_test = cross_validation.train_test_split(
X, Y, test_size=0.14,random_state=0)

# %%
print("X_train : ") #unnormalize
print(X_train*(np.max(X_before)-np.min(X_before))+np.min(X_before))
print("Y_train : ")
print(Y_train*(np.max(Y_before)-np.min(Y_before))+np.min(Y_before))
print("X_test : ")
print(X_test*(np.max(X_before)-np.min(X_before))+np.min(X_before))
print("Y_test : ")
print(Y_test*(np.max(Y_before)-np.min(Y_before))+np.min(Y_before))
# Out:
# X_train :
# [[  270.  1000.    80.    50.]
#  [  230.  1000.    80.    30.]
#  [  270.  1000.    60.    40.]
#  [  250.   800.   100.    40.]
#  [  250.  1000.    80.    40.]
#  [  270.  1000.   100.    40.]
#  [  230.  1000.    60.    40.]
#  [  250.   800.    80.    50.]
#  [  250.  1000.   100.    30.]
#  [  250.  1200.    80.    50.]
#  [  250.  1000.    80.    40.]
#  [  250.  1000.    60.    30.]
#  [  250.  1000.    60.    50.]
#  [  250.  1000.    80.    40.]
#  [  250.  1200.    80.    30.]
#  [  250.   800.    60.    40.]
#  [  270.   800.    80.    40.]
#  [  250.   800.    80.    30.]
#  [  230.  1000.   100.    40.]
#  [  250.  1000.   100.    50.]
#  [  250.  1200.    60.    40.]
#  [  270.  1000.    80.    30.]
#  [  270.  1200.    80.    40.]]
# Y_train :
# [ 1001.  1284.  1405.   799.  1053.   987.  1335.   701.  1133.  1317.
#   1123.  1349.  1342.  1151.  1380.  1007.   853.   810.   983.  1023.
#   1640.  1072.  1801.]
# X_test :
# [[  230.   800.    80.    40.]
#  [  230.  1000.    80.    50.]
#  [  230.  1200.    80.    40.]
#  [  250.  1200.   100.    40.]]
# Y_test :
# [  758.  1076.  1414.  1216.]

# %%
import tensorflow as tf

tf.set_random_seed(777)  # for reproducibility
learning_rate = 0.01

X = tf.placeholder(tf.float32, [None, 4])
Y = tf.placeholder(tf.float32, [None, ])

W1 = tf.Variable(tf.random_normal([4, 3]), name='weight1')
b1 = tf.Variable(tf.random_normal([3]), name='bias1')
layer1 = tf.nn.relu(tf.matmul(X, W1) + b1)

W2 = tf.Variable(tf.random_normal([3, 4]), name='weight2')
b2 = tf.Variable(tf.random_normal([4]), name='bias2')
layer2 = tf.nn.relu(tf.matmul(layer1, W2) + b2)

W3 = tf.Variable(tf.random_normal([4, 3]), name='weight3')
b3 = tf.Variable(tf.random_normal([3]), name='bias3')
layer3 = tf.nn.relu(tf.matmul(layer2, W3) + b3)

W4 = tf.Variable(tf.random_normal([3, 2]), name='weight4')
b4 = tf.Variable(tf.random_normal([2]), name='bias4')
layer4 = tf.nn.relu(tf.matmul(layer3, W4) + b4)

W5 = tf.Variable(tf.random_normal([2, 1]), name='weight5')
b5 = tf.Variable(tf.random_normal([1]), name='bias5')
hypothesis = tf.nn.sigmoid(tf.matmul(layer4, W5) + b5) #hypothesis is y_predict

# cost/loss function
# cost = -tf.reduce_mean(Y * tf.log(hypothesis) + (1 - Y) * tf.log(1 - hypothesis))<-Logistic
cost = tf.reduce_mean(tf.square(hypothesis - Y)) # <-Linear

train = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost)
#cost를 최소화 하는 형태로 learning_rate의 학습률을 가지고 gradient descent를 실행하겠다.

def R_squared(y, y_pred):
  residual = tf.reduce_sum(tf.square(tf.subtract(y, y_pred)))
  total = tf.reduce_sum(tf.square(tf.subtract(y, tf.reduce_mean(y))))
  r2 = tf.subtract(1.0, tf.divide(residual, total))
  return r2

# Launch graph
with tf.Session() as sess: #기존에는 session을 열고 닫아야 하지만, with를 사용하면 with가 끝난 후 자동으로 닫힌다.
    # Initialize TensorFlow variables
    sess.run(tf.global_variables_initializer())

    for step in range(20000):
        sess.run(train, feed_dict={X: X_train, Y: Y_train})
        if step % 100 == 0:
            print(step, sess.run(cost, feed_dict={
                  X: X_train, Y: Y_train})) #, sess.run([W1, W2]))

    # Accuracy report
    # h, c, a = sess.run([hypothesis, predicted, accuracy],
    #                   feed_dict={X: X_test, Y: Y_test})
    
    h = sess.run( hypothesis, feed_dict={X: X_test, Y: Y_test})
    
    print("\nHypothesis: ", h)
    #print( "\nCorrect: ", c)
    #print("\nAccuracy: ", a)
    print("\nrealY: ", Y_test)

    print("\nHypothesis: ")
    print(h*(np.max(Y_before)-np.min(Y_before))+np.min(Y_before))

    print("realY")
    print(Y_test*(np.max(Y_before)-np.min(Y_before))+np.min(Y_before))
    
    mse = mean_squared_error(Y_test, h)
    print("MSE: %.4f" % mse)
    
    Rsquare = R_squared(Y, h)
    #total_error = tf.reduce_sum(tf.square(tf.subtract(Y, tf.reduce_mean(Y))))
    #unexplained_error = tf.reduce_sum(tf.square(tf.subtract(Y, h)))
    #R_squared = tf.subtract(1, tf.div(unexplained_error, total_error))
    print("R^2: %.4f" % Rsquare)
# Out:
# 0 0.187488
# 100 0.059416
# 200 0.0590782
# 300 0.0590284
# 400 0.0589809
# 500 0.0589355
# 600 0.0588922
# 700 0.0588506
# 800 0.0588108
# 900 0.0587727
# 1000 0.0587361
# 1100 0.058701
# 1200 0.0586672
# 1300 0.0586347
# 1400 0.0586034
# 1500 0.0585733
# 1600 0.0585443
# 1700 0.0585163
# 1800 0.0584892
# 1900 0.0584631
# 2000 0.0584378
# 2100 0.0584134
# 2200 0.0583897
# 2300 0.0583668
# 2400 0.0583445
# 2500 0.0583229
# 2600 0.0583019
# 2700 0.0582816
# 2800 0.0582618
# 2900 0.0582425
# 3000 0.0582238
# 3100 0.0582056
# 3200 0.0581878
# 3300 0.0581705
# 3400 0.0581536
# 3500 0.0581372
# 3600 0.0581211
# 3700 0.0581054
# 3800 0.0580901
# 3900 0.0580752
# 4000 0.0580606
# 4100 0.0580463
# 4200 0.0580324
# 4300 0.0580188
# 4400 0.0580054
# 4500 0.0579924
# 4600 0.0579796
# 4700 0.0579672
# 4800 0.057955
# 4900 0.057943
# 5000 0.0579313
# 5100 0.0579198
# 5200 0.0579086
# 5300 0.0578976
# 5400 0.0578868
# 5500 0.0578763
# 5600 0.0578659
# 5700 0.0578558
# 5800 0.0578459
# 5900 0.0578361
# 6000 0.0578266
# 6100 0.0578173
# 6200 0.0578081
# 6300 0.0577987
# 6400 0.0577894
# 6500 0.0577802
# 6600 0.0577708
# 6700 0.0577611
# 6800 0.0577518
# 6900 0.0577427
# 7000 0.057734
# 7100 0.0577255
# 7200 0.0577172
# 7300 0.0577093
# 7400 0.0577015
# 7500 0.057694
# 7600 0.0576863
# 7700 0.0576785
# 7800 0.0576707
# 7900 0.0576623
# 8000 0.0576533
# 8100 0.0576442
# 8200 0.0576352
# 8300 0.0576267
# 8400 0.0576186
# 8500 0.057611
# 8600 0.0576032
# 8700 0.0575953
# 8800 0.0575869
# 8900 0.057578
# 9000 0.057569
# 9100 0.0575603
# 9200 0.0575521
# 9300 0.0575442
# 9400 0.0575366
# 9500 0.0575293
# 9600 0.0575224
# 9700 0.0575158
# 9800 0.0575094
# 9900 0.0575033
# 10000 0.0574975
# 10100 0.057492
# 10200 0.0574867
# 10300 0.0574816
# 10400 0.0574767
# 10500 0.0574721
# 10600 0.0574677
# 10700 0.0574634
# 10800 0.0574615
# 10900 0.0574605
# 11000 0.0574597
# 11100 0.0574591
# 11200 0.0574585
# 11300 0.0574579
# 11400 0.0574573
# 11500 0.0574567
# 11600 0.0574562
# 11700 0.0574556
# 11800 0.057455
# 11900 0.0574544
# 12000 0.0574539
# 12100 0.0574533
# 12200 0.0574527
# 12300 0.0574522
# 12400 0.0574516
# 12500 0.0574511
# 12600 0.0574505
# 12700 0.05745
# 12800 0.0574494
# 12900 0.0574489
# 13000 0.0574483
# 13100 0.0574478
# 13200 0.0574472
# 13300 0.0574467
# 13400 0.0574462
# 13500 0.0574456
# 13600 0.0574451
# 13700 0.0574446
# 13800 0.0574441
# 13900 0.0574435
# 14000 0.057443
# 14100 0.0574425
# 14200 0.057442
# 14300 0.0574415
# 14400 0.057441
# 14500 0.0574405
# 14600 0.0574399
# 14700 0.0574395
# 14800 0.0574389
# 14900 0.0574385
# 15000 0.057438
# 15100 0.0574375
# 15200 0.057437
# 15300 0.0574365
# 15400 0.057436
# 15500 0.0574355
# 15600 0.0574351
# 15700 0.0574346
# 15800 0.0574341
# 15900 0.0574336
# 16000 0.0574332
# 16100 0.0574327
# 16200 0.0574322
# 16300 0.0574318
# 16400 0.0574313
# 16500 0.0574309
# 16600 0.0574304
# 16700 0.05743
# 16800 0.0574295
# 16900 0.057429
# 17000 0.0574286
# 17100 0.0574282
# 17200 0.0574277
# 17300 0.0574273
# 17400 0.0574268
# 17500 0.0574264
# 17600 0.057426
# 17700 0.0574255
# 17800 0.0574251
# 17900 0.0574247
# 18000 0.0574243
# 18100 0.0574238
# 18200 0.0574234
# 18300 0.057423
# 18400 0.0574226
# 18500 0.0574222
# 18600 0.0574218
# 18700 0.0574214
# 18800 0.057421
# 18900 0.0574206
# 19000 0.0574201
# 19100 0.0574198
# 19200 0.0574193
# 19300 0.057419
# 19400 0.0574186
# 19500 0.0574182
# 19600 0.0574178
# 19700 0.0574174
# 19800 0.057417
# 19900 0.0574166
#
# Hypothesis:  [[ 0.41749814]
#  [ 0.40952834]
#  [ 0.3956998 ]
#  [ 0.39868197]]
#
# realY:  [ 0.05181818  0.34090909  0.64818182  0.46818182]
#
# Hypothesis:
# [[ 1160.2479248 ]
#  [ 1151.48120117]
#  [ 1136.26977539]
#  [ 1139.5501709 ]]
# realY
# [  758.  1076.  1414.  1216.]
# MSE: 0.0518
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-8d19f801fac6> in <module>()
#      75     #unexplained_error = tf.reduce_sum(tf.square(tf.subtract(Y, h)))
#      76     #R_squared = tf.subtract(1, tf.div(unexplained_error, total_error))
# ---> 77     print("R^2: %.4f" % Rsquare)
#
# TypeError: a float is required
