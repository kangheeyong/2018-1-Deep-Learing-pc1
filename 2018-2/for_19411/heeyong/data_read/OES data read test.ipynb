# %% [markdown]
# # OES data read test

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
a= np.fromfile('OES_data_set/2018-09-07_08h38m49s', dtype='int32')
a = np.reshape(a, (3650,3648))
a.shape
# Out:
# (3650, 3648)

# %%
a[3649][3647]
# Out:
# 2871

# %%
plt.imshow(a, cmap='Greys_r')
plt.savefig('result')
a_max = np.amax(a)
a_min = np.amin(a)

print(a_max, a_min)

b = (a - a_min)/(a_max-a_min)*255
# Out:
# 7564 2640

# %%
c = cv2.resize(b, None, fx=0.5, fy=0.5, interpolation=cv2.INTER_AREA)

plt.imshow(c, cmap='Greys_r')

# %%
c = cv2.resize(b, None, fx=0.1, fy=1, interpolation=cv2.INTER_NEAREST)

plt.imshow(c, cmap='Greys_r')

# %%
# Out:
# <built-in method max of numpy.ndarray object at 0x7fbb953a2e40>

# %%
shrink.shape
# Out:
# (1825, 1824)

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax2 = fig.add_subplot(1,1,1,projection='3d')
x,y = np.mgrid[:c.shape[0],:c.shape[1]]
ax2.plot_surface(x,y,c,cmap=plt.cm.jet,rstride=1,cstride=1,linewidth=0.,antialiased=False)
ax2.set_title('3D')
ax2.set_zlim3d(0,100)
# Out:
# (0, 100)
